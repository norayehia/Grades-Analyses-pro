# %%
import pandas as pd

students = pd.read_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/NLP GRADES(T.A).xlsx")
grades = pd.read_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/Nlp assignment 2 (Responses).xlsx")

# %%
grades.head(2)
# Out:
#                 Timestamp          Email Address                   Name  \
# 0 2025-11-22 21:24:29.575     noribm92@gmail.com                   Nora
# 1 2025-11-23 10:10:46.943  bighamood10@gmail.com  Mohamed Ahmed Younis
#
#           ID     نموذج                    مشروع فكره  رقم الجروب  \
# 0          0  Answer.A                            Non          0
# 1  223101291       A,B  Product documentation system           7
#
#                                             اجابه 1q  \
# 0  # --------------------------------------------...
# 1  import spacy\nfrom sklearn.feature_extraction....
#
#                                              اجابه2q \nاجابه q3 أن وجد  grade  \
# 0  # Q2: COUNTVECTORIZER 1–2 GRAMS\n# -----------...               Non    3.5
# 1  import spacy\nfrom sklearn.feature_extraction....              Null    4.0
#
#   project1 Unnamed: 12 Unnamed: 13
# 0      NaN         NaN         NaN
# 1      NaN         NaN         NaN

# %%
students.head(2)
# Out:
#   Subject code           ID                                        Name  \
# 0       AIE241  221101035.0     Akram Salah Mohamed Hasanin Badr al-Din
# 1       AIE241  221101050.0  Omar Essam Ezz Eldein Abdel Maksoud Hassan
#
#    Quiz 1 (10 Grades)  Quiz 2 (10 Grades)  Assignment 1 (4 Grades)  \
# 0                10.0                 NaN                      NaN
# 1                10.0                 NaN                      NaN
#
#    Assignment 2 (4 Grades)  Attendance (2 Grades)  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
#
#    Project Lab Work (10 Grades)  Total  Project Exam (10 Grades)  Total.1
# 0                           NaN    NaN                       NaN      NaN
# 1                           NaN    NaN                       NaN      NaN

# %%
# تنظيف ID في ملف الطلبة
"""

students["id"] = (
    students["id"]
        .astype(str)
        .str.strip()
        .str.replace(r"\s+", "", regex=True)
)

# تنظيف ID في ملف الدرجات
grades["id"] = (
    grades["id"]
        .astype(str)
        .str.strip()
        .str.replace(r"\s+", "", regex=True)
)

# %%
# تنظيف ID في ملف الطلبة وتحويل أي float لـ string بدون .0
students["ID"] = (
    students["ID"]
        .fillna(0)
        .apply(lambda x: str(int(x)) if isinstance(x, float) else str(x))  # 221101035.0 → "221101035"
        .str.strip()
        .str.replace(r"\s+", "", regex=True)
)

# تنظيف ID في ملف الدرجات بنفس الطريقة
grades["ID"] = (
    grades["ID"]
        .fillna(0)
        .apply(lambda x: str(int(x)) if isinstance(x, float) else str(x))
        .str.strip()
        .str.replace(r"\s+", "", regex=True)
)

# %%
students.head(2)
# Out:
#   Subject code         ID                                        Name  \
# 0       AIE241  221101035     Akram Salah Mohamed Hasanin Badr al-Din
# 1       AIE241  221101050  Omar Essam Ezz Eldein Abdel Maksoud Hassan
#
#    Quiz 1 (10 Grades)  Quiz 2 (10 Grades)  Assignment 1 (4 Grades)  \
# 0                10.0                 NaN                      NaN
# 1                10.0                 NaN                      NaN
#
#    Assignment 2 (4 Grades)  Attendance (2 Grades)  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
#
#    Project Lab Work (10 Grades)  Total  Project Exam (10 Grades)  Total.1
# 0                           NaN    NaN                       NaN      NaN
# 1                           NaN    NaN                       NaN      NaN

# %%
# اختيار عمودين فقط من ملف الدرجات
grades = grades[["ID", "grade"]]

# عمل LEFT JOIN
merged = pd.merge(students, grades, on="ID", how="left")
#merged["grade"] = merged["grade"].fillna("No grade")
missing_ids = set(grades["ID"]) - set(students["ID"])

# نضيف الصفوف المفقودة برمز "❌"
for mid in missing_ids:
    merged = pd.concat([merged, pd.DataFrame({"id":[mid], "grade":["❌"]})], ignore_index=True)
# حفظ في نفس ملف الطلاب
merged.to_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/NLP GRADES(T.A).xlsx", index=False)

# %% [markdown]
# تجرسيى

# %%
import pandas as pd

students = pd.read_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/NLP GRADES(T.A).xlsx")
grades = pd.read_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/attendace-share-NLP GRADES(T.A) .xlsx")

# %%
# تنظيف ID في ملف الطلبة وتحويل أي float لـ string بدون .0
students["ID"] = (
    students["ID"]
        .fillna(0)
        .apply(lambda x: str(int(x)) if isinstance(x, float) else str(x))  # 221101035.0 → "221101035"
        .str.strip()
        .str.replace(r"\s+", "", regex=True)
)

# تنظيف ID في ملف الدرجات بنفس الطريقة
grades["ID"] = (
    grades["ID"]
        .fillna(0)
        .apply(lambda x: str(int(x)) if isinstance(x, float) else str(x))
        .str.strip()
        .str.replace(r"\s+", "", regex=True)
)

# %% [markdown]
# هنا كان بس كان ضفنا عمود نفسه لفايل طلاب عند دكتوره  لكن مش ملينا عمود عندها

# %%
# اختيار عمودين فقط من ملف الدرجات
grades = grades[["ID", "Assignment تجريبى (4 Grades)"]]

# عمل LEFT JOIN
merged = pd.merge(students, grades, on="ID", how="left")
#merged["grade"] = merged["grade"].fillna("No grade")

# حفظ في نفس ملف الطلاب
merged.to_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/NLP GRADES(T.A).xlsx", index=False)

# %% [markdown]
# ===============================================================================================================================================================

# %%
import pandas as pd
import numpy as np

# --- 1. Define File Names ---
# Assuming the file with 'Academic ID' and 'درجه كويز 10' is the source.
GRADES_FILE = '/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/nora.Grades'

# Assuming the file with 'ID' and 'Quiz 1 (10 Grades)' is the target.
TARGET_FILE = '/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/NLP GRADES(T.A).xlsx'

OUTPUT_FILE = 'Updated_NLP_GRADES.xlsx'

# --- 2. Read DataFrames from Excel Files ---
# Reading the first sheet (default) of the Excel files
df_grades = pd.read_excel(GRADES_FILE)
df_target = pd.read_excel(TARGET_FILE)

# %%
df_grades.head(3)
# Out:
#   Academic ID                  Student Name (AR)  Group  درجه  كويز 10
# 0   221101035    اكرم صلاح محمد حسانين بدر الدين    7.0           10.0
# 1   221101035    اكرم صلاح محمد حسانين بدر الدين    7.0           10.0
# 2   221101050  عمر عصام عز الدين عبد المقصود حسن    9.0            NaN

# %%
# --- 3. Clean and Prepare Grades DataFrame ---

# Rename the 'Academic ID' column to 'ID' for merging purposes
df_grades = df_grades.rename(columns={'Academic ID': 'ID'})

# Drop duplicate rows based on ID, keeping the first occurrence
df_grades = df_grades.drop_duplicates(subset=['ID'], keep='first')

# %%
df_grades.head(2)
# Out:
#           ID                  Student Name (AR)  Group  درجه  كويز 10
# 0  221101035    اكرم صلاح محمد حسانين بدر الدين    7.0           10.0
# 2  221101050  عمر عصام عز الدين عبد المقصود حسن    9.0            NaN

# %%
df_grades.shape
# Out:
# (212, 4)

# %%
df_target.head(3)
# Out:
#   Subject code         ID                                  Name  \
# 0       AIE241  223101076        Ahmed Ehab Saad Youssef Khalil
# 1       AIE241  223101079     Ahmed Hamdy Amer Mohamed Ali Amer
# 2       AIE241  223101120  Ahmed Tawakkol Al-Saeed Ragab Satour
#
#    Quiz 1 (10 Grades)  Quiz 2 (10 Grades)  Assignment 1 (4 Grades)  \
# 0                 NaN                 NaN                      NaN
# 1                 NaN                 NaN                      NaN
# 2                 NaN                 NaN                      NaN
#
#    Assignment 2 (4 Grades)  Attendance (2 Grades)  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
#
#    Project Lab Work (10 Grades)  Total  Project Exam (10 Grades)  Total.1
# 0                           NaN    NaN                       NaN        0
# 1                           NaN    NaN                       NaN        0
# ...

# %%
# Perform a left merge to keep all students from the target file
df_merged = pd.merge(
    df_target,
    df_grades,
    on='ID',
    how='left'
)

# %%
# --- 5. Transfer Grades and Clean Up ---

# Transfer the values from the temporary Arabic grade column to the target English column.
# Use fillna('') to keep empty grades as blank strings, matching the format of the input file.
df_merged['Quiz 1 (10 Grades)'] = df_merged['درجه  كويز 10'].fillna('')

# %%
df_merged.head(2)
# Out:
#   Subject code         ID                               Name  \
# 0       AIE241  223101076     Ahmed Ehab Saad Youssef Khalil
# 1       AIE241  223101079  Ahmed Hamdy Amer Mohamed Ali Amer
#
#   Quiz 1 (10 Grades)  Quiz 2 (10 Grades)  Assignment 1 (4 Grades)  \
# 0                                    NaN                      NaN
# 1                8.0                 NaN                      NaN
#
#    Assignment 2 (4 Grades)  Attendance (2 Grades)  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
#
#    Project Lab Work (10 Grades)  Total  Project Exam (10 Grades)  Total.1  \
# 0                           NaN    NaN                       NaN        0
# 1                           NaN    NaN                       NaN        0
#
#               Student Name (AR)  Group  درجه  كويز 10
# 0      احمد ايهاب سعد يوسف خليل    1.0            NaN
# 1  احمد حمدي عامر محمد علي عامر    1.0            8.0

# %%
count_before_transfer = df_grades['درجه  كويز 10'].count()

# %%
df_grades['درجه  كويز 10'].count()
# Out:
# np.int64(110)

# %%
# لحساب عدد القيم المملوءة في عمود محدد داخل إطار البيانات (DataFrame)
number_of_filled_cells = df_grades['درجه  كويز 10'].count()

print(f"عدد الخلايا المملوءة في العمود هو: {number_of_filled_cells}")
# Out:
# عدد الخلايا المملوءة في العمود هو: 110

# %%
# لحساب عدد القيم المملوءة في عمود محدد داخل إطار البيانات (DataFrame)
number_of_filled_cells2 = df_final['Quiz 1 (10 Grades)'].count()

print(f"عدد الخلايا المملوءة في العمود هو: {number_of_filled_cells2}")
# Out:
# عدد الخلايا المملوءة في العمود هو: 206

# %%
# Remove the temporary column used for merging
df_final = df_merged.drop(columns=['درجه  كويز 10'])

# --- 6. Save the Updated Data to a New Excel File ---
df_final.to_excel(OUTPUT_FILE, index=False)

print(f"\n✅ Merging complete. The updated grades are saved to a new file: {OUTPUT_FILE}")
print("\nFirst few rows of the updated file:")
print(df_final.head().to_string(index=False))
# Out:
# ✅ Merging complete. The updated grades are saved to a new file: Updated_NLP_GRADES.xlsx
#
# First few rows of the updated file:
# Subject code        ID                                    Name Quiz 1 (10 Grades)  Quiz 2 (10 Grades)  Assignment 1 (4 Grades)  Assignment 2 (4 Grades)  Attendance (2 Grades)  Project Lab Work (10 Grades)  Total  Project Exam (10 Grades)  Total.1                  Student Name (AR)  Group
#       AIE241 223101076          Ahmed Ehab Saad Youssef Khalil                                    NaN                      NaN                      NaN                    NaN                           NaN    NaN                       NaN        0           احمد ايهاب سعد يوسف خليل    1.0
# ...

# %% [markdown]
# #To check

# %%
import pandas as pd

# اقرأ الملفين
f1 = pd.read_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/nora.Gradesnodublicate.xlsx")
f2 = pd.read_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/NLP GRADES(T.A).xlsx")

# توحيد اسم الأعمدة
f1 = f1.rename(columns={"Academic ID": "ID", "Quiz 1 (10 Grades)": "Quiz1"})

# %%
f1 = f1.rename(columns={"Academic ID": "ID", "Quiz 1 (10 Grades)": "Quiz1"})

# %%
f2 = f2.rename(columns={"Academic ID": "ID", "Quiz 1 (10 Grades)": "Quiz1"})

# %%
f1.head()
# Out:
#           ID                               Student Name (AR)  Group  Quiz1
# 0  221101035                 اكرم صلاح محمد حسانين بدر الدين    7.0   10.0
# 1  221101050               عمر عصام عز الدين عبد المقصود حسن    9.0    NaN
# 2  222101329  عبدالحميد عبدالناصر عبدالحميد حامد اسماعيل على    7.0   10.0
# 3  222101340                   ابراهيم اسامه صالح عبد الجواد    7.0    NaN
# 4  222101344                     دانه عادل عبد الحميد النبوى    7.0   10.0

# %%
f2.head()
# Out:
#   Subject code           ID                                     Name  Quiz1  \
# 0       AIE241  223101076.0           Ahmed Ehab Saad Youssef Khalil    NaN
# 1       AIE241  223101079.0        Ahmed Hamdy Amer Mohamed Ali Amer    8.0
# 2       AIE241  223101120.0     Ahmed Tawakkol Al-Saeed Ragab Satour    NaN
# 3       AIE241  223101122.0   Ahmed Raafat Mohamed Abdel Salam Sayed    NaN
# 4       AIE241  223101133.0  Aya Al-Saeed Mahmoud Al-Saeed Al-Hanafy    NaN
#
#    Quiz 2 (10 Grades)  Assignment 1 (4 Grades)  Assignment 2 (4 Grades)  \
# 0                 NaN                      NaN                      NaN
# 1                 NaN                      NaN                      NaN
# 2                 NaN                      NaN                      NaN
# 3                 NaN                      NaN                      NaN
# 4                 NaN                      NaN                      NaN
#
#    Attendance (2 Grades)  Project Lab Work (10 Grades)  Total  \
# ...

# %%
# الطلاب اللي درجاتهم ناقصة في كل ملف
missing_f1 = set(f1[f1["Quiz1"].isnull()]["ID"])
missing_f2 = set(f2[f2["Quiz1"].isnull()]["ID"])

print("Missing in File 1:", missing_f1)
print("Missing in File 2:", missing_f2)
# Out:
# Missing in File 1: {222101506, 222101509, 222101516, 222101528, 222101536, 222101552, 222101566, 222101567, nan, 223101070, 223101073, 223101074, 223101075, 223101076, 223101081, 223101086, 223101092, 223101093, 223101101, 223101103, 223101110, 223101114, 223101116, 223101120, 223101122, 223101123, 223101128, 223101130, 223101131, 223101133, 223101137, 223101143, 223101146, 223101147, 223101149, 223101153, 223101155, 223101159, 223101160, 223101169, 223101171, 223101175, 223101178, 223101179, 223101182, 223101183, 223101196, 223101197, 223101203, 223101211, 223101215, 223101221, 223101228, 223101229, 223101230, 223101239, 223101261, 223101266, 223101270, 222101340, 223101278, 223101282, 223101287, 222101358, 222101363, 223101303, 222101368, 222101369, 223101313, 223101316, 223101317, 223101322, 223101323, 222101393, 222101395, 223101331, 222101398, 223101336, 222101403, 223101339, 222101405, 223101340, 223101341, 223101343, 222101411, 223101350, 222101416, 222101429, 222101437, 22310
# ...

# %%
# هل نفس missing؟؟
if missing_f1 == missing_f2:
    print("\n✔️ نفس الطلاب missing في الملفين بالضبط")
else:
    print("\n❌ فيه اختلاف في الطلاب اللي missing")
    print("Students missing only in File 1:", missing_f1 - missing_f2)
    print("Students missing only in File 2:", missing_f2 - missing_f1)
# Out:
# ❌ فيه اختلاف في الطلاب اللي missing
# Students missing only in File 1: {222101477, 222101509, nan, 223101303, 223101175}
# Students missing only in File 2: set()

# %%
import pandas as pd
import math

# تحويل كل العناصر في Missing 1 إلى string والتخلص من nan
clean_f1 = {str(x).split('.')[0] for x in missing_f1 if pd.notna(x)}

# تحويل Missing 2 إلى string بدون .0
clean_f2 = {str(int(x)) for x in missing_f2 if not math.isnan(x)}

print("Clean Missing F1:", clean_f1)
print("Clean Missing F2:", clean_f2)

# المقارنة
if clean_f1 == clean_f2:
    print("\n✔️ نفس الطلبة بالضبط missing في الملفين")
else:
    print("\n❌ فيه اختلاف في الطلبة missing")
    print("✨ موجودين في File 1 بس:", clean_f1 - clean_f2)
    print("✨ موجودين في File 2 بس:", clean_f2 - clean_f1)
# Out:
# Clean Missing F1: {'223101287', '223101197', '222101528', '222101566', '223101147', '223101114', '222101411', '223101179', '222101368', '223101373', '222101369', '223101175', '223101343', '222101405', '222101567', '223101133', '223101159', '223101171', '223101317', '223101323', '222101492', '223101350', '223101266', '223101093', '223101076', '223101149', '223101086', '223101183', '223101270', '223101120', '223101103', '223101073', '222101552', '223101331', '222101395', '222101536', '223101074', '223101278', '223101092', '223101381', '223101229', '223101122', '223101221', '223101130', '222101516', '223101146', '223101153', '222101416', '222101363', '223101137', '223101230', '222101403', '223101261', '223101128', '223101239', '223101313', '223101101', '223101303', '222101469', '223101143', '223101339', '223101182', '222101398', '223101336', '222101461', '223101215', '222101506', '223101116', '222101393', '222101462', '223101081', '223101131', '223101341', '223101378', '221101050', '223
# ...

# %% [markdown]
# لذين:
# # موجودين في الملف الأول + عندهم درجة
# # ومفقودين في الملف الثاني

# %%
# IDs كـ string
f1["ID"] = f1["ID"].astype(str)
f2["ID"] = f2["ID"].astype(str)

# الطلاب اللي عندهم قيمه في ملف 1 (مش missing)
has_value_f1 = f1[f1["Quiz1"].notnull()]

# الطلاب اللي مفيهمش قيمه في ملف 2 (missing)
missing_f2 = f2[f2["Quiz1"].isnull()]

# نجيب IDs الذين:
# موجودين في الملف الأول + عندهم درجة
# ومفقودين في الملف الثاني
result = has_value_f1[has_value_f1["ID"].isin(missing_f2["ID"])]

print("الطلاب اللي عندهم درجة في ملف 1 ومفيش ليهم درجة في ملف 2:")
print(result)
# Out:
# الطلاب اللي عندهم درجة في ملف 1 ومفيش ليهم درجة في ملف 2:
# Empty DataFrame
# Columns: [ID, Student Name (AR), Group, Quiz1]
# Index: []

# %%
# Standardize ID column
f1["ID"] = f1["ID"].astype(str).str.split('.').str[0]
f2["ID"] = f2["ID"].astype(str).str.split('.').str[0]

# IDs في كل ملف
ids_f1 = set(f1["ID"])
ids_f2 = set(f2["ID"])

# الطلبة الموجودين في file1 ومش موجودين في file2
missing_students = ids_f1 - ids_f2

print("الطلبة اللي موجودين في الملف الأول ومش موجودين في الملف التاني:")
print(missing_students)
# Out:
# الطلبة اللي موجودين في الملف الأول ومش موجودين في الملف التاني:
# {'222101477', '223101303', '222101498', 'cont', '23101123', '222101509'}

# %% [markdown]
# ----------------------------------------------------------------------assignment2

# %%
import pandas as pd

# اقرأ الملفين
f1 = pd.read_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/thinking/_Nlp assignment 3 (Responses).xlsx")
f2 = pd.read_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/NLP GRADES(T.A).xlsx")

# توحيد اسم الأعمدة

# %%
f1.head(3)
# Out:
#                 Timestamp                                 Name           Id  \
# 0 2025-12-07 10:28:35.526  Abdelrhman Mohamed Ahmed Al Ghonimi  223101228.0
# 1 2025-12-07 10:28:57.749           Samah Ashraf Saad Elmenady  223101198.0
# 2 2025-12-07 10:29:06.268                Mohamed Ahmed Younis   223101291.0
#
#   نموذج                      مشروع فكره  رقم الجروب  \
# 0     A                            Rafiq      الاحد
# 1     A                            Rafiq   sunday 9
# 2     A  Product recommendations system      Ais 7
#
#                                             اجابه 1q  \
# 0  https://www.kaggle.com/code/abdelrhmanalghonim...
# 1  https://colab.research.google.com/drive/1njm6p...
# 2  import pandas as pd\nfrom textblob import Text...
#
#                                              اجابه2q  \
# 0                                                  0
# 1                                                  0
# 2  import pandas as pd\nfrom sklearn.feature_extr...
#
# ...

# %%
f2.head(2)
# Out:
#   Subject code         ID                                        Name  \
# 0       AIE241  221101035     Akram Salah Mohamed Hasanin Badr al-Din
# 1       AIE241  221101050  Omar Essam Ezz Eldein Abdel Maksoud Hassan
#
#    Quiz 1 (10 Grades)  Quiz 2 (10 Grades)  Assignment تجريبى  \
# 0                10.0                 NaN                NaN
# 1                10.0                 NaN                NaN
#
#    Assignment 1 (4 Grades)  Assignment 2 (4 Grades)  Attendance (2 Grades)  \
# 0                      3.5                      NaN                    NaN
# 1                      3.5                      NaN                    NaN
#
#    Project Lab Work (10 Grades)  total  Project Exam (10 Grades)  Final Total
# 0                           NaN    NaN                       NaN          NaN
# 1                           NaN    NaN                       NaN          NaN

# %%
f1['Id'] = f1['Id'].astype(str).str.replace('.0', '', regex=False)

# %%
f1.head(2)
# Out:
#                 Timestamp                                 Name         Id  \
# 0 2025-12-07 10:28:35.526  Abdelrhman Mohamed Ahmed Al Ghonimi  223101228
# 1 2025-12-07 10:28:57.749           Samah Ashraf Saad Elmenady  223101198
#
#   نموذج مشروع فكره  رقم الجروب  \
# 0     A       Rafiq      الاحد
# 1     A       Rafiq   sunday 9
#
#                                             اجابه 1q اجابه2q  \
# 0  https://www.kaggle.com/code/abdelrhmanalghonim...       0
# 1  https://colab.research.google.com/drive/1njm6p...       0
#
#   \nاجابه q3 أن وجد   q4 Column 1  grade
# 0                 0  NaN      NaN    4.0
# 1                 0    0      NaN    4.0

# %%
f1["Id"] = pd.to_numeric(f1["Id"], errors='coerce').fillna(0).astype(int)
f2["ID"] = pd.to_numeric(f2["ID"], errors='coerce').fillna(0).astype(int)

# %%
f2 = f2.merge(
    f1[["Id", "grade"]],
    left_on="ID",
    right_on="Id",
    how="left"
)

# %%
f2["Assignment 2 (4 Grades)"] = f2["Assignment 2 (4 Grades)"].fillna(f2["grade"])

# %%
f2.head(1)
# Out:
#   Subject code         ID                                     Name  \
# 0       AIE241  221101035  Akram Salah Mohamed Hasanin Badr al-Din
#
#    Quiz 1 (10 Grades)  Quiz 2 (10 Grades)  Assignment تجريبى  \
# 0                10.0                 NaN                NaN
#
#    Assignment 1 (4 Grades)  Assignment 2 (4 Grades)  Attendance (2 Grades)  \
# 0                      3.5                      4.0                    NaN
#
#    Project Lab Work (10 Grades)  total  Project Exam (10 Grades)  Final Total  \
# 0                           NaN    NaN                       NaN          NaN
#
#             Id  grade
# 0  221101035.0    4.0

# %%
f1.head(5)
# Out:
#                 Timestamp                                   Name         Id  \
# 0 2025-12-07 10:28:35.526    Abdelrhman Mohamed Ahmed Al Ghonimi  223101228
# 1 2025-12-07 10:28:57.749             Samah Ashraf Saad Elmenady  223101198
# 2 2025-12-07 10:29:06.268                  Mohamed Ahmed Younis   223101291
# 3 2025-12-07 10:42:11.957  عمرو صلاح ابو السعود عبدالاه البابلي   223101257
# 4 2025-12-07 10:44:07.546            Sayed Ahmed Sayed Tag Eldin  222101484
#
#   نموذج                      مشروع فكره     رقم الجروب  \
# 0     A                            Rafiq         الاحد
# 1     A                            Rafiq      sunday 9
# 2     A  Product recommendations system         Ais 7
# 3     A          Proudect recommendation             7
# 4     A                            Rafiq  sunday 9am 6
#
#                                             اجابه 1q  \
# 0  https://www.kaggle.com/code/abdelrhmanalghonim...
# 1  https://colab.research.google.com/drive/1njm6p...
# ...

# %%
# نقل grade إلى Assignment 2
#grade_map = f1.set_index("Id")["grade"]
#f2["Assignment 2 (4 Grades)"] = f2["ID"].map(grade_map)

# حفظ التعديل في نفس الملف (⚠️ نفس المسار)
f2.to_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/NLP GRADES(T.A).xlsx", index=False)

# %% [markdown]
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,projects

# %%
f3 = pd.read_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/5grades2 Team member-nlp.xlsx")

# %%
f3.head(2)
# Out:
#                    -           ID ideaproject  \
# 0   Ahmed Hamdy Amer  223101079.0  AI Clinic
# 1  Sama Selim Hashim  223101197.0   AI Clinic
#
#   لينك داريف صوره لما تم وصول به أو فيديوا أن امكن الجروب     معاد السكشن  \
# 0                                              NaN     G1  Thursday 12:20
# 1                                              NaN     G1  Thursday 12:20
#
#   اسم التيم او الرقم ما تم انجازه حتى يوم 30 شهر 10  ماتم  انجازه 6 شهر 12  \
# 0             CliniQ                             NaN                   NaN
# 1             CliniQ                             NaN                   NaN
#
#   مناقشه يوم    pr2   Pr1 Unnamed: 12  Unnamed: 13  Unnamed: 14
# 0    الاربعاء  10.0  10.0         NaN          NaN          NaN
# 1    الاربعاء   9.5  10.0         NaN          NaN          NaN

# %%
f3['ID'] = f3['ID'].astype(str).str.replace('.0', '', regex=False)

# %%
f3["ID"] = pd.to_numeric(f3["ID"], errors='coerce').fillna(0).astype(int)

# %%
f3.head(3)
# Out:
#                     -         ID ideaproject  \
# 0    Ahmed Hamdy Amer  223101079  AI Clinic
# 1   Sama Selim Hashim  223101197   AI Clinic
# 2  Jana sameh Mohamed  223101145   AI Clinic
#
#   لينك داريف صوره لما تم وصول به أو فيديوا أن امكن الجروب     معاد السكشن  \
# 0                                              NaN     G1  Thursday 12:20
# 1                                              NaN     G1  Thursday 12:20
# 2                                              NaN     G1  Thursday 12:20
#
#   اسم التيم او الرقم ما تم انجازه حتى يوم 30 شهر 10  ماتم  انجازه 6 شهر 12  \
# 0             CliniQ                             NaN                   NaN
# 1             CliniQ                             NaN                   NaN
# 2             CliniQ                             NaN                   NaN
#
#   مناقشه يوم    pr2   Pr1 Unnamed: 12  Unnamed: 13  Unnamed: 14
# 0    الاربعاء  10.0  10.0         NaN          NaN          NaN
# ...

# %%
f2 = f2.merge(
    f3[["ID", "ideaproject"]],
    left_on="ID",
    right_on="ID",
    how="left"
)

# %%
f2.head(2)
# Out:
#   Subject code         ID                                        Name  \
# 0       AIE241  221101035     Akram Salah Mohamed Hasanin Badr al-Din
# 1       AIE241  221101050  Omar Essam Ezz Eldein Abdel Maksoud Hassan
#
#    Quiz 1 (10 Grades)  Quiz 2 (10 Grades)  Assignment تجريبى  \
# 0                10.0                 NaN                NaN
# 1                10.0                 NaN                NaN
#
#    Assignment 1 (4 Grades)  Assignment 2 (4 Grades)  Attendance (2 Grades)  \
# 0                      3.5                      4.0                    NaN
# 1                      3.5                      4.0                    NaN
#
#    Project Lab Work (10 Grades)  total  Project Exam (10 Grades)  Final Total  \
# 0                           NaN    NaN                       NaN          NaN
# 1                           NaN    NaN                       NaN          NaN
#
#             Id  grade ideaproject
# 0  221101035.0    4.0         NaN
# ...

# %%
f2.to_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/NLP GRADES(T.A).xlsx", index=False)

# %%
f2 = f2.merge(
    f3[["ID", "Pr1","pr2"]],
    left_on="ID",
    right_on="ID",
    how="left"
)

# %%
f2.to_excel("/content/drive/MyDrive/Noribm92/nmu/Fullterm/Nlp/NLP GRADES(T.A).xlsx", index=False)
